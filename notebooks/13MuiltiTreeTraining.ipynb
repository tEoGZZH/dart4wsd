# %%
import os
import sys
sys.path.append('../src')
from util import load_balls, load_ball_dims, load_semcor_data, format_sense_id, get_eval_pair
from dataset import nballDataset
from model import nballBertNorm, nballBertDirection

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from tqdm import tqdm
import torch.nn.functional as F

# %%
# Read all the roots name
directory_path = '../data/entity_multi'
# Initialize an empty list to store the extracted file names
roots = []

# Loop through each file in the specified directory
for file in os.listdir(directory_path):
    # Check if the file name matches the format xxx_nball.txt
    if file.endswith('_nball.txt'):
        # Extract the xxx part and add it to the list
        root = file.split('_nball.txt')[0]
        roots.append(root)

print(f"Numbers of the roots:{len(roots)}")
# Out:
# Numbers of the roots:81

# %%
# Read original Tree
def read_tree(wsChildrenFile = None):
    wsChildrenDic = dict()
    if os.path.isfile(wsChildrenFile):
        with open(wsChildrenFile, 'r') as chfh:
            for ln in chfh:
                wlst = ln[:-1].split()
                wsChildrenDic[wlst[0]] = wlst[1:]
    return wsChildrenDic

# Read files
wsChildrenFile = "D:\\OtherProject\\dart4wsd\\data\\entity_multi\\wsChildren.txt"
wsChildrenDic = read_tree(wsChildrenFile)

# %%
# Read training and eval corpra
# Load data
train_semcor_path = {
    "xml":'../data/WSD_Evaluation_Framework/Training_Corpora/Semcor/semcor.data.xml',
    "gold_key":'../data/WSD_Evaluation_Framework/Training_Corpora/Semcor/semcor.gold.key.txt',}

eval_all_path = {
    "xml":'../data/WSD_Evaluation_Framework/Evaluation_Datasets/ALL/ALL.data.xml',
    "gold_key":'../data/WSD_Evaluation_Framework/Evaluation_Datasets/ALL/ALL.gold.key.txt',}

training_corpra = load_semcor_data(train_semcor_path)

# %%
# Formate the sense id in training corpra
sense_id_cache = {}
training_corpra['formatted_sense_id'] = training_corpra['sense_id'].apply(lambda x: format_sense_id(x, sense_id_cache))

# %%
# Calculate roots level
from collections import deque

def calculate_node_levels(tree, roots):
    # Initialize a dictionary to store the levels
    root_levels = {}

    # Perform a BFS or DFS from each subroot to calculate levels
    for root in roots:
        # Initialize a queue for BFS with tuples (node, level)
        queue = deque([(root, 1)])  # Start at level 1 for the root

        while queue:
            current_node, current_level = queue.popleft()

            # If the current node is already in node_levels, continue
            if current_node in root_levels:
                continue

            # Assign the level to the current node
            root_levels[current_node] = current_level

            # Add children nodes to the queue
            for child in tree.get(current_node, []):
                queue.append((child, current_level + 1))

    return root_levels

root_levels = calculate_node_levels(wsChildrenDic, roots)
root_levels["entity.n.01"] = 0

sorted_nodes = sorted(root_levels.items(), key=lambda x: x[1])
for node, level in sorted_nodes:
    print(f"Node: {node}, Level: {level}")
# Out:
# Node: entity.n.01, Level: 0
# Node: ability.n.02, Level: 1
# Node: abstraction.n.06, Level: 1
# Node: adult.n.01, Level: 1
# Node: advocate.n.01, Level: 1
# Node: amerindian.n.01, Level: 1
# Node: animal.n.01, Level: 1
# Node: artifact.n.01, Level: 1
# Node: asian.n.01, Level: 1
# Node: capitalist.n.02, Level: 1
# Node: communicator.n.01, Level: 1
# Node: contestant.n.01, Level: 1
# Node: creator.n.02, Level: 1
# Node: entertainer.n.01, Level: 1
# Node: aptitude.n.01, Level: 2
# Node: art.n.03, Level: 2
# Node: bilingualism.n.01, Level: 2
# Node: capacity.n.08, Level: 2
# Node: creativity.n.01, Level: 2
# Node: faculty.n.01, Level: 2
# Node: hand.n.04, Level: 2
# Node: intelligence.n.01, Level: 2
# Node: know-how.n.01, Level: 2
# Node: leadership.n.04, Level: 2
# Node: originality.n.01, Level: 2
# Node: skill.n.01, Level: 2
# Node: skill.n.02, Level: 2
# Node: attribute.n.02, Level: 2
# Node: cognition.n.01, Level: 2
# Node: communication.n.02, Level: 2
# Node: event.n.01, Level: 2
# Node: group.n.01, Level: 2
# Node: measure.n.02, Level: 2
# Node: motivation.n.01, Level: 2
# Node: otherworld.n.01, Level: 2
# Node: relation.n.01, Level: 2
# Node: set.n.02, Level: 2
# Node: brachycephalic.n.01, Level: 2
# Node: caregiver.n.02, Level: 2
# Node: catch.n.03, Level: 2
# Node: celebrity.n.01, Level: 2
# Node: centrist.n.01, Level: 2
# Node: character.n.05, Level: 2
# Node: colossus.n.02, Level: 2
# Node: conservative.n.01, Level: 2
# Node: elder.n.01, Level: 2
# Node: excellency.n.01, Level: 2
# Node: fixer.n.01, Level: 2
# Node: hierarch.n.01, Level: 2
# Node: host.n.01, Level: 2
# Node: kingmaker.n.02, Level: 2
# Node: kingpin.n.01, Level: 2
# Node: knocker.n.01, Level: 2
# Node: liberal.n.01, Level: 2
# Node: liberal.n.02, Level: 2
# Node: magnifico.n.01, Level: 2
# Node: militarist.n.01, Level: 2
# Node: name.n.04, Level: 2
# Node: oldster.n.01, Level: 2
# Node: pacifist.n.01, Level: 2
# Node: patrician.n.01, Level: 2
# Node: pawnbroker.n.01, Level: 2
# Node: pledger.n.01, Level: 2
# Node: professional.n.01, Level: 2
# Node: sirdar.n.01, Level: 2
# Node: socialite.n.01, Level: 2
# Node: sophisticate.n.01, Level: 2
# Node: stay-at-home.n.01, Level: 2
# Node: stoic.n.02, Level: 2
# Node: sun.n.03, Level: 2
# Node: supremo.n.01, Level: 2
# Node: thoroughbred.n.01, Level: 2
# Node: worthy.n.01, Level: 2
# Node: apologist.n.01, Level: 2
# Node: constitutionalist.n.01, Level: 2
# Node: darwinian.n.01, Level: 2
# Node: democrat.n.02, Level: 2
# Node: federalist.n.02, Level: 2
# Node: gnostic.n.01, Level: 2
# Node: humanist.n.02, Level: 2
# Node: ideologist.n.01, Level: 2
# Node: internationalist.n.01, Level: 2
# Node: irredentist.n.01, Level: 2
# Node: isolationist.n.01, Level: 2
# Node: jansenist.n.01, Level: 2
# Node: libertarian.n.01, Level: 2
# Node: maoist.n.01, Level: 2
# Node: marxist.n.01, Level: 2
# Node: nationalist.n.02, Level: 2
# Node: neoclassicist.n.01, Level: 2
# Node: neutralist.n.01, Level: 2
# Node: nullifier.n.01, Level: 2
# Node: partisan.n.01, Level: 2
# Node: platonist.n.01, Level: 2
# Node: presenter.n.02, Level: 2
# Node: protectionist.n.01, Level: 2
# Node: republican.n.02, Level: 2
# Node: ritualist.n.01, Level: 2
# Node: secessionist.n.01, Level: 2
# Node: secularist.n.01, Level: 2
# Node: aleut.n.01, Level: 3
# Node: algonquian.n.01, Level: 3
# Node: anasazi.n.01, Level: 3
# Node: arapaho.n.01, Level: 3
# Node: atakapa.n.01, Level: 3
# Node: athapaskan.n.01, Level: 3
# Node: blackfoot.n.01, Level: 3
# Node: caddo.n.01, Level: 3
# Node: cheyenne.n.03, Level: 3
# Node: chickasaw.n.01, Level: 3
# Node: choctaw.n.01, Level: 3
# Node: creek.n.02, Level: 3
# Node: eskimo.n.01, Level: 3
# Node: haida.n.01, Level: 3
# Node: hitchiti.n.01, Level: 3
# Node: hokan.n.02, Level: 3
# Node: iroquois.n.01, Level: 3
# Node: kiowa.n.01, Level: 3
# Node: koasati.n.01, Level: 3
# Node: mayan.n.01, Level: 3
# Node: muskogee.n.01, Level: 3
# Node: nahuatl.n.01, Level: 3
# Node: ojibwa.n.01, Level: 3
# Node: olmec.n.01, Level: 3
# Node: penutian.n.02, Level: 3
# Node: pima.n.01, Level: 3
# Node: pueblo.n.01, Level: 3
# Node: redskin.n.01, Level: 3
# Node: salish.n.02, Level: 3
# Node: seminole.n.01, Level: 3
# Node: shoshone.n.01, Level: 3
# Node: sioux.n.01, Level: 3
# Node: squaw.n.01, Level: 3
# Node: tarahumara.n.01, Level: 3
# Node: tlingit.n.01, Level: 3
# Node: wakashan.n.01, Level: 3
# Node: zapotec.n.01, Level: 3
# Node: inca.n.02, Level: 3
# Node: tunicate.n.01, Level: 3
# Node: vertebrate.n.01, Level: 3
# Node: appenzeller.n.01, Level: 3
# Node: basenji.n.01, Level: 3
# Node: boxer.n.04, Level: 3
# Node: briard.n.01, Level: 3
# Node: bulldog.n.01, Level: 3
# Node: chihuahua.n.03, Level: 3
# Node: collie.n.01, Level: 3
# Node: corgi.n.01, Level: 3
# Node: courser.n.03, Level: 3
# Node: cur.n.01, Level: 3
# Node: dachshund.n.01, Level: 3
# Node: dalmatian.n.02, Level: 3
# Node: griffon.n.02, Level: 3
# ...
# Node: reviewer.n.01, Level: 10
# Node: taster.n.01, Level: 10
# Node: lolita.n.01, Level: 10
# Node: damsel.n.01, Level: 10
# Node: io.n.01, Level: 10
# Node: odalisque.n.01, Level: 10
# Node: cajun.n.01, Level: 10
# Node: burgess.n.02, Level: 10
# Node: cornishman.n.01, Level: 10
# Node: jacobean.n.01, Level: 10
# Node: limey.n.01, Level: 10
# Node: tory.n.02, Level: 10
# Node: cockney.n.01, Level: 10
# Node: galatian.n.01, Level: 10
# Node: parisienne.n.01, Level: 10
# Node: junker.n.01, Level: 10
# Node: mafioso.n.01, Level: 10
# Node: latinist.n.01, Level: 10
# Node: murray.n.01, Level: 10
# Node: wolf.n.03, Level: 10
# Node: furnivall.n.01, Level: 10
# Node: humboldt.n.01, Level: 10
# Node: muller.n.05, Level: 10
# Node: murray.n.02, Level: 10
# Node: rask.n.01, Level: 10
# Node: skeat.n.01, Level: 10
# Node: verner.n.01, Level: 10
# Node: huguenot.n.01, Level: 10
# Node: heidegger.n.01, Level: 10
# Node: sartre.n.01, Level: 10
# Node: egalitarian.n.01, Level: 10
# Node: elitist.n.01, Level: 10
# Node: utilitarian.n.01, Level: 10
# Node: pragmatist.n.01, Level: 10
# Node: augur.n.01, Level: 10
# Node: prophetess.n.01, Level: 10
# Node: sibyl.n.02, Level: 10
# Node: nostradamus.n.01, Level: 10
# Node: sibyl.n.01, Level: 10
# Node: maintenon.n.01, Level: 10
# Node: montespan.n.01, Level: 10
# Node: pompadour.n.01, Level: 10
# Node: landgrave.n.01, Level: 10
# Node: baron.n.02, Level: 10
# Node: cornwallis.n.01, Level: 10
# Node: duke.n.01, Level: 10
# Node: earl.n.01, Level: 10
# Node: marquess.n.02, Level: 10
# Node: viscount.n.02, Level: 10
# Node: viscountess.n.02, Level: 10
# Node: graham.n.01, Level: 10
# Node: mcpherson.n.01, Level: 10
# Node: moody.n.02, Level: 10
# Node: roberts.n.02, Level: 10
# Node: sunday.n.02, Level: 10
# Node: televangelist.n.01, Level: 10
# Node: postmistress.n.01, Level: 10
# Node: manageress.n.01, Level: 10
# Node: gore.n.01, Level: 10
# Node: insider.n.01, Level: 10
# Node: minister.n.02, Level: 10
# Node: president.n.01, Level: 10
# Node: rainmaker.n.01, Level: 10
# Node: ritz.n.01, Level: 10
# Node: exarch.n.03, Level: 10
# Node: khedive.n.01, Level: 10
# Node: rep.n.01, Level: 10
# Node: clinton.n.01, Level: 10
# Node: fulbright.n.01, Level: 10
# Node: glenn.n.01, Level: 10
# Node: pinko.n.01, Level: 10
# Node: apparatchik.n.02, Level: 10
# Node: bolshevik.n.02, Level: 10
# Node: comrade.n.02, Level: 10
# Node: revisionist.n.01, Level: 10
# Node: stalin.n.01, Level: 10
# Node: thatcher.n.01, Level: 10
# Node: kazan.n.01, Level: 10
# Node: stanislavsky.n.01, Level: 10
# Node: baas.n.01, Level: 10
# Node: ganger.n.01, Level: 10
# Node: ramrod.n.02, Level: 10
# Node: yeoman.n.02, Level: 10
# Node: landlady.n.01, Level: 10
# Node: cheapskate.n.01, Level: 10
# Node: hauler.n.01, Level: 10
# Node: subcontractor.n.01, Level: 10
# Node: corespondent.n.01, Level: 10
# Node: respondent.n.01, Level: 10
# Node: freemason.n.01, Level: 10
# Node: beguine.n.01, Level: 10
# Node: conventioneer.n.01, Level: 10
# Node: partygoer.n.01, Level: 10
# Node: eavesdropper.n.01, Level: 10
# Node: concierge.n.01, Level: 10
# Node: superintendent.n.02, Level: 10
# Node: warrener.n.01, Level: 10
# Node: lookout.n.01, Level: 10
# Node: patroller.n.01, Level: 10
# Node: hickock.n.01, Level: 10
# Node: bobby.n.01, Level: 10
# Node: bull.n.05, Level: 10
# Node: captain.n.03, Level: 10
# Node: constable.n.03, Level: 10
# Node: detective.n.01, Level: 10
# Node: gendarme.n.01, Level: 10
# Node: inspector.n.01, Level: 10
# Node: mountie.n.01, Level: 10
# Node: shoofly.n.01, Level: 10
# Node: trooper.n.02, Level: 10
# Node: trooper.n.03, Level: 10
# Node: matron.n.02, Level: 10
# Node: grandfather.n.01, Level: 10
# Node: grandma.n.01, Level: 10
# Node: abraham.n.01, Level: 10
# Node: antediluvian.n.01, Level: 10
# Node: benjamin.n.02, Level: 10
# Node: isaac.n.01, Level: 10
# Node: ishmael.n.01, Level: 10
# Node: issachar.n.01, Level: 10
# Node: jacob.n.02, Level: 10
# Node: joseph.n.02, Level: 10
# Node: judah.n.01, Level: 10
# Node: methuselah.n.01, Level: 10
# Node: noah.n.01, Level: 10
# Node: reuben.n.01, Level: 10
# Node: simeon.n.01, Level: 10
# Node: father.n.01, Level: 10
# Node: mother.n.01, Level: 10
# Node: stepparent.n.01, Level: 10
# Node: cherub.n.01, Level: 10
# Node: foundling.n.01, Level: 10
# Node: godchild.n.01, Level: 10
# Node: neonate.n.01, Level: 10
# Node: papoose.n.01, Level: 10
# Node: stepdaughter.n.01, Level: 10
# Node: stepson.n.01, Level: 10
# Node: carter.n.01, Level: 10
# Node: champollion.n.01, Level: 10
# Node: salk.n.01, Level: 10
# Node: hubel.n.01, Level: 10
# Node: lepidopterist.n.01, Level: 10
# Node: wilson.n.07, Level: 10
# Node: audubon.n.01, Level: 10
# Node: wilson.n.03, Level: 10
# Node: hoyle.n.01, Level: 10
# Node: hubble.n.01, Level: 10
# Node: lemaitre.n.01, Level: 10
# Node: slammer.n.01, Level: 10
# Node: bowie.n.01, Level: 10
# Node: burk.n.01, Level: 10
# Node: bushman.n.02, Level: 10
# Node: chapman.n.01, Level: 10
# Node: frontiersman.n.01, Level: 10
# Node: no-show.n.01, Level: 10
# Node: regular.n.01, Level: 10
# Node: shopaholic.n.01, Level: 10
# Node: alcoholic.n.01, Level: 10
# Node: cutter.n.02, Level: 10
# Node: vegan.n.01, Level: 10
# Node: damocles.n.01, Level: 10
# Node: raleigh.n.01, Level: 10
# Node: minder.n.01, Level: 10
# Node: usher.n.03, Level: 10
# Node: armiger.n.01, Level: 10
# Node: stewardess.n.01, Level: 10
# Node: parer.n.01, Level: 10
# Node: chippendale.n.01, Level: 10
# Node: joseph.n.03, Level: 10
# Node: pitchman.n.01, Level: 10
# Node: bunny.n.01, Level: 10
# Node: bracero.n.01, Level: 10
# Node: cleaner.n.03, Level: 10
# Node: cowboy.n.01, Level: 10
# Node: digger.n.01, Level: 10
# Node: dishwasher.n.02, Level: 10
# Node: drudge.n.02, Level: 10
# Node: farmhand.n.01, Level: 10
# Node: gravedigger.n.01, Level: 10
# Node: herder.n.02, Level: 10
# Node: hewer.n.01, Level: 10
# Node: itinerant.n.01, Level: 10
# Node: lumberman.n.01, Level: 10
# Node: miner.n.01, Level: 10
# Node: peasant.n.02, Level: 10
# Node: porter.n.01, Level: 10
# Node: sawyer.n.01, Level: 10
# Node: sharecropper.n.01, Level: 10
# Node: sprayer.n.01, Level: 10
# Node: stacker.n.01, Level: 10
# Node: steeplejack.n.01, Level: 10
# Node: stevedore.n.01, Level: 10
# Node: stoker.n.02, Level: 10
# Node: woodcutter.n.01, Level: 10
# Node: wrecker.n.01, Level: 10
# Node: remover.n.02, Level: 10
# Node: pilate.n.01, Level: 10
# Node: ambassadress.n.01, Level: 10
# Node: gromyko.n.01, Level: 10
# Node: stipendiary.n.01, Level: 10
# Node: coxswain.n.01, Level: 10
# Node: master.n.07, Level: 10
# Node: mate.n.01, Level: 10
# Node: privateer.n.01, Level: 10
# Node: purser.n.01, Level: 10
# Node: steward.n.02, Level: 10
# Node: supercargo.n.01, Level: 10
# Node: chambermaid.n.01, Level: 10
# Node: handmaid.n.02, Level: 10
# Node: cuirassier.n.01, Level: 10
# Node: dragoon.n.01, Level: 10
# Node: hussar.n.01, Level: 10
# Node: lancer.n.01, Level: 10
# Node: doughboy.n.01, Level: 10
# Node: fusilier.n.01, Level: 10
# Node: grenadier.n.01, Level: 10
# Node: musketeer.n.01, Level: 10
# Node: minuteman.n.01, Level: 10
# Node: abettor.n.01, Level: 10
# Node: confederate.n.02, Level: 10
# Node: barnburner.n.01, Level: 10
# Node: fawkes.n.01, Level: 10
# Node: oates.n.01, Level: 10
# Node: absconder.n.01, Level: 10
# Node: escapee.n.01, Level: 10
# Node: apache.n.02, Level: 10
# Node: capone.n.01, Level: 10
# Node: yakuza.n.01, Level: 10
# Node: yardie.n.01, Level: 10
# Node: bully.n.02, Level: 10
# Node: crimp.n.02, Level: 10
# Node: bagman.n.02, Level: 10
# Node: coyote.n.02, Level: 10
# Node: gunrunner.n.01, Level: 10
# Node: bandit.n.01, Level: 10
# Node: booster.n.03, Level: 10
# Node: burglar.n.01, Level: 10
# Node: dacoit.n.01, Level: 10
# Node: embezzler.n.01, Level: 10
# Node: pickpocket.n.01, Level: 10
# Node: plagiarist.n.01, Level: 10
# Node: plunderer.n.01, Level: 10
# Node: robber.n.01, Level: 10
# Node: rustler.n.01, Level: 10
# Node: snatcher.n.01, Level: 10
# Node: turpin.n.01, Level: 10
# Node: arnold.n.02, Level: 10
# Node: collaborator.n.02, Level: 10
# Node: immortelle.n.01, Level: 10
# Node: popcorn.n.01, Level: 10
# Node: sorghum.n.01, Level: 10
# Node: durum.n.01, Level: 10
# Node: emmer.n.01, Level: 10
# Node: spelt.n.01, Level: 10
# Node: single-leaf.n.01, Level: 10
# Node: anglo-catholicism.n.01, Level: 11
# Node: revivalism.n.01, Level: 11
# Node: salafism.n.01, Level: 11
# Node: shiism.n.01, Level: 11
# Node: wahhabism.n.01, Level: 11
# Node: hasidism.n.02, Level: 11
# Node: recirculation.n.01, Level: 11
# Node: roundhouse.n.02, Level: 11
# Node: redeye.n.01, Level: 11
# Node: matricide.n.02, Level: 11
# Node: patricide.n.02, Level: 11
# Node: alamo.n.01, Level: 11
# Node: bloodbath.n.01, Level: 11
# Node: backstop.n.03, Level: 11
# Node: security.n.09, Level: 11
# Node: reshuffle.n.02, Level: 11
# Node: riffle.n.02, Level: 11
# Node: bill.n.04, Level: 11
# Node: reinterpretation.n.02, Level: 11
# Node: spin.n.05, Level: 11
# Node: sedation.n.02, Level: 11
# Node: doubling.n.02, Level: 11
# Node: raid.n.02, Level: 11
# Node: caper.n.03, Level: 11
# Node: dacoity.n.01, Level: 11
# Node: heist.n.01, Level: 11
# Node: highjacking.n.01, Level: 11
# Node: rolling.n.02, Level: 11
# Node: natural.n.03, Level: 11
# Node: adjunct.n.03, Level: 11
# Node: clause.n.01, Level: 11
# Node: complement.n.01, Level: 11
# Node: involution.n.02, Level: 11
# Node: phrase.n.01, Level: 11
# Node: predicate.n.01, Level: 11
# Node: referent.n.02, Level: 11
# Node: subject.n.08, Level: 11
# Node: enkephalin.n.01, Level: 11
# Node: laetrile.n.01, Level: 11
# Node: aldose.n.01, Level: 11
# Node: fructose.n.01, Level: 11
# Node: hexose.n.01, Level: 11
# Node: pentose.n.01, Level: 11
# Node: disaccharide.n.01, Level: 11
# Node: cellulose.n.01, Level: 11
# Node: chitin.n.01, Level: 11
# Node: dextrin.n.01, Level: 11
# Node: glycogen.n.01, Level: 11
# Node: heparin.n.01, Level: 11
# Node: inulin.n.01, Level: 11
# Node: starch.n.01, Level: 11
# Node: butterfat.n.01, Level: 11
# Node: cracklings.n.01, Level: 11
# Node: drippings.n.01, Level: 11
# Node: lard.n.01, Level: 11
# Node: marbling.n.01, Level: 11
# Node: myelin.n.01, Level: 11
# Node: shortening.n.01, Level: 11
# Node: suet.n.01, Level: 11
# Node: attar.n.01, Level: 11
# Node: blubber.n.01, Level: 11
# Node: grease.n.01, Level: 11
# Node: lanolin.n.01, Level: 11
# Node: lemongrass.n.01, Level: 11
# Node: linalool.n.01, Level: 11
# Node: petroleum.n.01, Level: 11
# Node: tallow.n.01, Level: 11
# Node: turpentine.n.02, Level: 11
# Node: lecithin.n.01, Level: 11
# Node: beeswax.n.01, Level: 11
# Node: paraffin.n.01, Level: 11
# Node: spermaceti.n.01, Level: 11
# Node: antitoxin.n.01, Level: 11
# Node: autoantibody.n.01, Level: 11
# Node: infliximab.n.01, Level: 11
# Node: interleukin.n.01, Level: 11
# Node: amylase.n.01, Level: 11
# Node: catalase.n.01, Level: 11
# Node: cholinesterase.n.01, Level: 11
# Node: collagenase.n.01, Level: 11
# Node: complement.n.05, Level: 11
# Node: cyclooxygenase.n.01, Level: 11
# Node: decarboxylase.n.01, Level: 11
# Node: elastase.n.01, Level: 11
# Node: isomerase.n.01, Level: 11
# Node: kinase.n.01, Level: 11
# Node: lactase.n.01, Level: 11
# Node: lipase.n.01, Level: 11
# Node: lysozyme.n.01, Level: 11
# Node: nitrogenase.n.01, Level: 11
# Node: nuclease.n.01, Level: 11
# Node: oxidase.n.01, Level: 11
# Node: oxidoreductase.n.01, Level: 11
# Node: papain.n.01, Level: 11
# Node: pepsin.n.01, Level: 11
# Node: phosphatase.n.01, Level: 11
# Node: plasmin.n.01, Level: 11
# Node: polymerase.n.01, Level: 11
# Node: protease.n.01, Level: 11
# Node: reductase.n.01, Level: 11
# Node: secretase.n.01, Level: 11
# Node: streptokinase.n.01, Level: 11
# Node: telomerase.n.01, Level: 11
# Node: thrombin.n.01, Level: 11
# Node: transferase.n.01, Level: 11
# Node: trypsin.n.01, Level: 11
# Node: urease.n.01, Level: 11
# Node: myosin.n.01, Level: 11
# Node: transferrin.n.01, Level: 11
# Node: erythropoietin.n.01, Level: 11
# Node: lectin.n.01, Level: 11
# Node: mucin.n.01, Level: 11
# Node: casein.n.01, Level: 11
# Node: firestone.n.01, Level: 11
# Node: flintstone.n.01, Level: 11
# Node: gunflint.n.01, Level: 11
# Node: balm.n.01, Level: 11
# Node: tolu.n.01, Level: 11
# Node: styrofoam.n.01, Level: 11
# Node: centerfold.n.01, Level: 11
# Node: mileage.n.03, Level: 11
# Node: bobcat.n.01, Level: 11
# Node: caracal.n.01, Level: 11
# Node: bronco.n.01, Level: 11
# Node: affirmed.n.01, Level: 11
# Node: assault.n.03, Level: 11
# Node: citation.n.06, Level: 11
# Node: omaha.n.04, Level: 11
# Node: secretariat.n.02, Level: 11
# Node: whirlaway.n.01, Level: 11
# Node: springbok.n.01, Level: 11
# Node: gemsbok.n.01, Level: 11
# Node: kob.n.01, Level: 11
# Node: lechwe.n.01, Level: 11
# Node: zebu.n.01, Level: 11
# Node: ayrshire.n.01, Level: 11
# Node: beef.n.01, Level: 11
# Node: bull.n.01, Level: 11
# Node: cow.n.01, Level: 11
# Node: devon.n.02, Level: 11
# Node: friesian.n.01, Level: 11
# Node: grade.n.09, Level: 11
# Node: guernsey.n.02, Level: 11
# Node: jersey.n.05, Level: 11
# Node: ox.n.01, Level: 11
# Node: stirk.n.01, Level: 11
# Node: welsh.n.03, Level: 11
# Node: aurochs.n.02, Level: 11
# Node: banteng.n.01, Level: 11
# Node: gaur.n.01, Level: 11
# Node: yak.n.02, Level: 11
# Node: bellwether.n.02, Level: 11
# Node: nautilus.n.01, Level: 11
# Node: guinness.n.02, Level: 11
# Node: fringe.n.06, Level: 11
# Node: bilges.n.01, Level: 11
# Node: insole.n.01, Level: 11
# Node: outsole.n.01, Level: 11
# Node: tonsure.n.01, Level: 11
# Node: juror.n.01, Level: 11
# Node: scanner.n.01, Level: 11
# Node: mandarin.n.02, Level: 11
# Node: cassandra.n.01, Level: 11
# Node: montfort.n.01, Level: 11
# Node: astor.n.01, Level: 11
# Node: haman.n.01, Level: 11
# Node: treasury.n.04, Level: 11
# Node: yamani.n.01, Level: 11
# Node: bukharin.n.01, Level: 11
# Node: lenin.n.01, Level: 11
# Node: tapper.n.04, Level: 11
# Node: beria.n.01, Level: 11
# Node: dick.n.01, Level: 11
# Node: tracer.n.01, Level: 11
# Node: nan.n.01, Level: 11
# Node: dad.n.01, Level: 11
# Node: pater.n.01, Level: 11
# Node: ma.n.01, Level: 11
# Node: mary.n.01, Level: 11
# Node: mater.n.01, Level: 11
# Node: mother-in-law.n.01, Level: 11
# Node: supermom.n.01, Level: 11
# Node: stepfather.n.01, Level: 11
# Node: stepmother.n.01, Level: 11
# Node: goddaughter.n.01, Level: 11
# Node: godson.n.01, Level: 11
# Node: boone.n.01, Level: 11
# Node: carson.n.02, Level: 11
# Node: usherette.n.01, Level: 11
# Node: charwoman.n.01, Level: 11
# Node: cowgirl.n.01, Level: 11
# Node: gaucho.n.01, Level: 11
# Node: roper.n.02, Level: 11
# Node: vaquero.n.01, Level: 11
# Node: trencher.n.01, Level: 11
# Node: dairyman.n.02, Level: 11
# Node: gleaner.n.01, Level: 11
# Node: harvester.n.01, Level: 11
# Node: picker.n.02, Level: 11
# Node: plowman.n.01, Level: 11
# Node: sheepherder.n.01, Level: 11
# Node: swineherd.n.01, Level: 11
# Node: swagman.n.01, Level: 11
# Node: tinker.n.02, Level: 11
# Node: bunyan.n.02, Level: 11
# Node: scorer.n.02, Level: 11
# Node: prospector.n.01, Level: 11
# Node: fellah.n.01, Level: 11
# Node: redcap.n.02, Level: 11
# Node: skycap.n.01, Level: 11
# Node: knacker.n.01, Level: 11
# Node: kidd.n.01, Level: 11
# Node: hawkins.n.01, Level: 11
# Node: pirate.n.02, Level: 11
# Node: mugger.n.01, Level: 11
# Node: durra.n.01, Level: 11
# Node: kaoliang.n.01, Level: 11
# Node: milo.n.01, Level: 11
# Node: ismailism.n.01, Level: 12
# Node: chabad.n.02, Level: 12
# Node: piracy.n.01, Level: 12
# Node: catchphrase.n.01, Level: 12
# Node: predicate.n.02, Level: 12
# Node: response.n.05, Level: 12
# Node: glucose.n.01, Level: 12
# Node: lactose.n.01, Level: 12
# Node: maltose.n.01, Level: 12
# Node: pectin.n.01, Level: 12
# Node: pulp.n.03, Level: 12
# Node: amyloid.n.01, Level: 12
# Node: arrowroot.n.01, Level: 12
# Node: arum.n.01, Level: 12
# Node: cassava.n.01, Level: 12
# Node: cornstarch.n.01, Level: 12
# Node: sago.n.01, Level: 12
# Node: dubbin.n.01, Level: 12
# Node: antivenin.n.01, Level: 12
# Node: endonuclease.n.01, Level: 12
# Node: exonuclease.n.01, Level: 12
# Node: peroxidase.n.01, Level: 12
# Node: oxygenase.n.01, Level: 12
# Node: plasminogen.n.01, Level: 12
# Node: transcriptase.n.01, Level: 12
# Node: caspase.n.01, Level: 12
# Node: renin.n.01, Level: 12
# Node: ribonuclease.n.01, Level: 12
# Node: transaminase.n.01, Level: 12
# Node: trypsinogen.n.01, Level: 12
# Node: charolais.n.01, Level: 12
# Node: durham.n.02, Level: 12
# Node: galloway.n.02, Level: 12
# Node: hereford.n.01, Level: 12
# Node: longhorn.n.01, Level: 12
# Node: springer.n.02, Level: 12
# Node: foreperson.n.01, Level: 12
# Node: naomi.n.01, Level: 12
# Node: shepherdess.n.01, Level: 12
# Node: corsair.n.01, Level: 12
# Node: laffite.n.01, Level: 12
# Node: morgan.n.03, Level: 12
# Node: roberts.n.04, Level: 12
# Node: teach.n.01, Level: 12
# Node: dextrose.n.01, Level: 13
# Node: glucosamine.n.01, Level: 13
# Node: bagasse.n.01, Level: 13
# Node: foreman.n.02, Level: 13
# Node: forewoman.n.01, Level: 13
# Node: barbarossa.n.02, Level: 13

# %%
def find_subtree(tree, root, roots):
    """
    Find the nodes in the subtree of `root`, but do not expand the other roots.
    """
    subtree_nodes = set()
    queue = deque([root])

    while queue:
        current_node = queue.popleft()
        subtree_nodes.add(current_node)

        # If we encounter another root, don't expand it
        if current_node in roots and current_node != root:
            continue

        # Add children to the queue
        for child in tree.get(current_node, []):
            if child not in subtree_nodes:
                queue.append(child)
    # delete root from subtree_nodes
    subtree_nodes.discard(root)
    
    return subtree_nodes


def find_subtree_all(tree, root):
    """
    Find the nodes in the entire subtree of the given root, expanding all nodes including roots.
    """
    subtree_nodes = set()
    queue = deque([root])

    while queue:
        current_node = queue.popleft()
        subtree_nodes.add(current_node)

        # Add children to the queue
        for child in tree.get(current_node, []):
            if child not in subtree_nodes:
                queue.append(child)

    # delete root from subtree_nodes
    subtree_nodes.discard(root)
    
    return subtree_nodes


# Test
test_root = 'mammal.n.01'
subnodes_entity = find_subtree(wsChildrenDic, test_root, roots)
subroots = subnodes_entity.intersection(roots)
print(len(subnodes_entity))
print(len(subroots))
print(subroots)
# Out:
# 386
# 0
# set()

# %%
def filter_corpra(corpra, tree, root, roots):
    """
    Filter the corpora DataFrame for a specific root, replacing formatted_sense_id with the subroot.
    """
    # First, find the subtree nodes from the root in the tree (without expanding other roots)
    subtree_nodes = find_subtree(tree, root, roots)
    # Second, for the roots in the subtree nodes, replace all the nodes in their subtree with the root
    subroots = subtree_nodes.intersection(roots)
    for subroot in subroots:
        subtree_nodes_of_subroot = find_subtree_all(tree, subroot)
        # Replace:
        corpra.loc[corpra['formatted_sense_id'].isin(subtree_nodes_of_subroot), 'formatted_sense_id'] = subroot
    
    # Third, filter the corpora that "formatted_sense_id" in subtree_nodes
    filtered_corpra = corpra[corpra['formatted_sense_id'].isin(subtree_nodes)]
    filtered_corpra.reset_index(drop=True, inplace=True)

    return filtered_corpra

# Test
filtered_corpra = filter_corpra(training_corpra.copy(), wsChildrenDic, test_root, roots)
print(f"corpra length:{len(training_corpra)}, filtered corpra length:{len(filtered_corpra)}")

display(training_corpra[training_corpra['pos']=='NOUN'].head(10))
display(filtered_corpra.head(10))
# Out:
# corpra length:226036, filtered corpra length:338
#    sentence_id     instance_id         lemma   pos          word  \
# 3    d000.s000  d000.s000.t003     objective  NOUN    objectives
# 4    d000.s000  d000.s000.t004       benefit  NOUN       benefit
# 5    d000.s000  d000.s000.t005       service  NOUN       service
# 6    d000.s000  d000.s000.t006       program  NOUN       program
# 9    d000.s001  d000.s001.t002      giveaway  NOUN      giveaway
# 10   d000.s001  d000.s001.t003       program  NOUN       program
# 13   d000.s001  d000.s001.t006          goal  NOUN          goal
# 15   d000.s001  d000.s001.t008      employee  NOUN      employee
# 16   d000.s001  d000.s001.t009        morale  NOUN        morale
# 19   d000.s001  d000.s001.t012  productivity  NOUN  productivity
#
#                                         sentence_text                sense_id  \
# 3   How long has it been since you reviewed the ob...     objective%1:09:00::
# 4   How long has it been since you reviewed the ob...       benefit%1:21:00::
# 5   How long has it been since you reviewed the ob...       service%1:04:07::
# 6   How long has it been since you reviewed the ob...       program%1:09:01::
# 9   Have you permitted it to become a giveaway pro...      giveaway%1:21:00::
# 10  Have you permitted it to become a giveaway pro...       program%1:09:01::
# 13  Have you permitted it to become a giveaway pro...          goal%1:09:00::
# 15  Have you permitted it to become a giveaway pro...      employee%1:18:00::
# 16  Have you permitted it to become a giveaway pro...        morale%1:26:00::
# 19  Have you permitted it to become a giveaway pro...  productivity%1:07:00::
#
#      formatted_sense_id
# 3              aim.n.02
# 4          benefit.n.01
# 5          service.n.05
# 6          program.n.02
# 9         giveaway.n.01
# 10         program.n.02
# 13            goal.n.01
# 15        employee.n.01
# 16          morale.n.01
# 19  productiveness.n.01
#   sentence_id     instance_id     lemma   pos       word  \
# 0   d003.s049  d003.s049.t010       man  NOUN        men
# 1   d006.s007  d006.s007.t007     horse  NOUN      horse
# 2   d006.s013  d006.s013.t003   wildcat  NOUN    wildcat
# 3   d007.s061  d007.s061.t017      lion  NOUN      Lions
# 4   d007.s118  d007.s118.t012  elephant  NOUN  elephants
# 5   d011.s002  d011.s002.t009     bronc  NOUN     broncs
# 6   d011.s092  d011.s092.t002     horse  NOUN     horses
# 7   d011.s112  d011.s112.t003     bronc  NOUN      bronc
# 8   d011.s130  d011.s130.t002     bronc  NOUN      bronc
# 9   d011.s145  d011.s145.t001      pony  NOUN       pony
#
#                                        sentence_text            sense_id  \
# 0  Whereas the eighteenth century had been a time...       man%1:05:01::
# 1  One wrote : `` [ I am so hungry ] I could eat ...     horse%1:05:00::
# 2  She is well-educated and refined , all wildcat...   wildcat%1:05:00::
# 3  To find out , we traveled throughout that part...      lion%1:05:00::
# 4  The Prince visited the hospital of Operation B...  elephant%1:05:00::
# 5  Although they were forced to maintain a sharpe...     bronc%1:05:00::
# 6     Neither spoke till they reached their horses .     horse%1:05:00::
# 7  Giving the other a dark look , he hauled his b...     bronc%1:05:00::
# 8  Clapping spurs to the bronc he set off at a sh...     bronc%1:05:00::
# 9  Leading his pony , he hurried that way , not r...      pony%1:05:02::
#
#   formatted_sense_id
# 0          homo.n.02
# 1         horse.n.01
# 2       wildcat.n.03
# 3          lion.n.01
# 4      elephant.n.01
# 5        bronco.n.01
# 6         horse.n.01
# 7        bronco.n.01
# 8        bronco.n.01
# 9          pony.n.01

# %%
# Check
sub_all_abs = find_subtree_all(wsChildrenDic, "abstraction.n.06")
check = ["aim.n.02", "benefit.n.01", "service.n.05", "program.n.02", "giveaway.n.01", "goal.n.01", "morale.n.01", "productiveness.n.01"]
for c in check:
    print(c in sub_all_abs)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True

# %%
def preprocess_data(corpra, nball):
    # For corpra, it has been filtered and replaced within the subtree of the root
    sense_labels = list(nball.keys())
    sense_index = {sense: idx for idx, sense in enumerate(sense_labels)}
    lemma_labels, lemma_pair, eval_pair = get_eval_pair(sense_index)
    lemma_index = {lemma: idx for idx, lemma in enumerate(lemma_labels)}
    
    corpra['sense_idx'] = corpra['formatted_sense_id'].map(sense_index)
    # Problem about it
    # data_merged['lemma_idx'] = data_merged['lemma'].map(lemma_index)
    corpra['lemma_idx'] = corpra['formatted_sense_id'].apply(lambda x: lemma_index[x.split('.')[0]])
    corpra['sense_group'] = corpra['sense_idx'].map(eval_pair)
    # We keep those columns for now
    keys_to_keep = ['lemma', 'word', 'sentence_text', 'lemma_idx', 'formatted_sense_id', 'sense_idx', 'sense_group']
    corpra = corpra[keys_to_keep]

    return corpra, lemma_pair

# %%
def train(model, dataloader, optimizer, scheduler, num_epochs, mode, nball_target):
    last_loss = 0
    if mode == "norm":
        loss_fn = log_cosh_loss
    elif mode == "direction":
        loss_fn = nn.CosineEmbeddingLoss()
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        progress_bar = tqdm(dataloader, desc=f'Epoch {epoch+1}/{num_epochs}', leave=True, position=0)
        for batch in progress_bar:
            # Unpack batch and send to device
            batch_input_ids, batch_attention_masks, batch_word_indices, \
            batch_sense_indices, _, _ = [b.to(device) for b in batch]

            optimizer.zero_grad()
        
            # Forward pass
            output = model(input_ids=batch_input_ids, attention_mask=batch_attention_masks, \
                            word_index=batch_word_indices).squeeze()

            # print(output)
            if mode == "norm":
                batch_norms = nball_target[batch_sense_indices]
                loss = loss_fn(output, batch_norms * 1e-10)
            elif mode == "direction":
                labels = torch.ones(output.size(0), device=device)
                batch_senses = nball_target[batch_sense_indices]
                loss = loss_fn(output, batch_senses, labels)
                
            loss.backward()
            optimizer.step()
        
            total_loss += loss.item()
            progress_bar.set_postfix(loss=loss.item())

        # Logging average metrics per epoch
        avg_loss = total_loss / len(dataloader)
        improvement = (last_loss - total_loss) / len(dataloader) if last_loss != 0 else 0
        print(f'Epoch {epoch + 1}, Avg Loss: {avg_loss}, Improvement: {improvement}')
        last_loss = total_loss

        scheduler.step()

# %%
def log_cosh_loss(norm_u, norm_v):
    return torch.log(torch.cosh(norm_u - norm_v)).mean()

# %%
# train one tree
def train_one_tree(model_norm, root, training_data, device):
    # Preprocess data
    nball_path = '../data/entity_multi/' + root + "_nball.txt"
    nball = load_balls(nball_path)
    train_semcor, lemma_pair = preprocess_data(training_data, nball)

    
    # Load nball embeddings:
    sense_labels = list(nball.keys())
    nball_embeddings = [nball[label].center for label in sense_labels]
    nball_norms = [nball[label].distance for label in sense_labels]
    nball_radius = [nball[label].radius for label in sense_labels]

    
    # Data checking:
    # Sorting the lists
    nball_norms_sorted = sorted(nball_norms)
    nball_radius_sorted = sorted(nball_radius)
    # Getting the smallest 10 from each list
    smallest_10_norms = nball_norms_sorted[:10]
    smallest_10_radius = nball_radius_sorted[:10]
    # Getting the largest 10 from each list
    largest_10_norms = nball_norms_sorted[-10:]
    largest_10_radius = nball_radius_sorted[-10:]
    # Printing the results
    print("Smallest 10 elements in nball_norms:", smallest_10_norms)
    print("Largest 10 elements in nball_norms:", largest_10_norms)
    print("Smallest 10 elements in nball_radius:", smallest_10_radius)
    print("Largest 10 elements in nball_radius:", largest_10_radius)


    # Wrap as tensor
    nball_embeddings = torch.tensor(np.array(nball_embeddings), dtype=torch.float32).to(device)
    nball_norms = torch.tensor(np.array(nball_norms), dtype=torch.float32).to(device)
    nball_radius = torch.tensor(np.array(nball_radius), dtype=torch.float32).to(device)

    # Set dataset
    dataset_train = nballDataset(train_semcor, nball.keys(), model_url, max_length)
    dataloader_train = DataLoader(dataset_train, batch_size, shuffle=True)

    
    # Call train loop
    loss_fn_norm = log_cosh_loss
    optimizer_norm = optim.Adam([{'params': model_norm.parameters()}], lr=2e-5)
    scheduler_norm = StepLR(optimizer_norm, step_size=50, gamma=0.1)
    # Train_norm
    train(model=model_norm, \
          dataloader=dataloader_train,\
          optimizer=optimizer_norm,\
          scheduler=scheduler_norm,\
          num_epochs=2, \
          mode="norm",
          nball_target=nball_norms)
    
    # optimizer_d = optim.Adam([{'params': model_d.parameters()}], lr=2e-5)
    # scheduler_d = StepLR(optimizer_d, step_size=50, gamma=0.1)
    # # Train direction
    # train(model=model_d, \
    #       dataloader=dataloader_train,\
    #       optimizer=optimizer_d,\
    #       scheduler=scheduler_d,\
    #       num_epochs=20, \
    #       mode="direction")

    # return model_norm, model_d

# %%
# Get dimensions of the balls
directory_path = '../data/entity_multi'
# Initialize an empty list to store the extracted file names
ball_dims = {}

# Loop through each file in the specified directory
for root in roots:
    nball_path = '../data/entity_multi/' + root + "_nball.txt"
    ball_dims[root] = load_ball_dims(nball_path)


print(ball_dims)
# Out:
# {'ability.n.02': 157, 'abstraction.n.06': 155, 'act.n.02': 159, 'action.n.01': 159, 'activity.n.01': 160, 'adult.n.01': 158, 'advocate.n.01': 155, 'amerindian.n.01': 156, 'animal.n.01': 158, 'artifact.n.01': 159, 'asian.n.01': 155, 'attribute.n.02': 159, 'capitalist.n.02': 158, 'change.n.03': 158, 'chemical.n.01': 159, 'chordate.n.01': 154, 'cognition.n.01': 159, 'communication.n.02': 159, 'communicator.n.01': 158, 'condition.n.01': 158, 'content.n.05': 159, 'contestant.n.01': 157, 'covering.n.02': 158, 'creation.n.02': 159, 'creator.n.02': 157, 'device.n.01': 159, 'discipline.n.01': 157, 'diversion.n.01': 158, 'entertainer.n.01': 158, 'entity.n.01': 158, 'event.n.01': 160, 'expert.n.01': 159, 'female.n.02': 156, 'gathering.n.01': 156, 'genus.n.02': 153, 'group.n.01': 162, 'happening.n.01': 158, 'implement.n.01': 158, 'inhabitant.n.01': 156, 'instrumentality.n.03': 161, 'intellectual.n.01': 157, 'language.n.01': 158, 'leader.n.01': 157, 'location.n.01': 160, 'mammal.n.01': 160, 'material.n.01': 158, 'matter.n.03': 160, 'measure.n.02': 158, 'mechanism.n.05': 156, 'message.n.02': 158, 'motion.n.06': 157, 'municipality.n.01': 155, 'number.n.02': 157, 'object.n.01': 158, 'occupation.n.01': 157, 'organism.n.01': 156, 'organization.n.01': 158, 'part.n.01': 156, 'person.n.01': 158, 'plant.n.02': 158, 'property.n.02': 158, 'quality.n.01': 161, 'region.n.03': 157, 'relation.n.01': 161, 'relative.n.01': 158, 'ruler.n.01': 155, 'scientist.n.01': 156, 'signal.n.01': 157, 'state.n.02': 159, 'structure.n.01': 158, 'substance.n.01': 157, 'substance.n.07': 160, 'support.n.10': 156, 'thing.n.12': 159, 'traveler.n.01': 157, 'vertebrate.n.01': 159, 'whole.n.02': 158, 'work.n.01': 158, 'worker.n.01': 158, 'writing.n.02': 159, 'wrongdoer.n.01': 159}

# %%
# Test
test_root = 'ability.n.02'
filtered_corpra = filter_corpra(training_corpra.copy(), wsChildrenDic, test_root, roots)

subnodes_entity = find_subtree(wsChildrenDic, test_root, roots)
subroots = subnodes_entity.intersection(roots)
print(len(subnodes_entity))
print(len(subroots))
print(subroots)
# Out:
# 369
# 0
# set()

# %%
bert_models = {"BERT-Base": ["bert-base-uncased", 768], #768, 12L, 12A
               "BERT-Large": ["bert-large-uncased", 1024], #1024, 24L, 16A
               "BERT-Medium": ["google/bert_uncased_L-8_H-512_A-8", 512], #512, 8L, 8A
               "BERT-Small": ["google/bert_uncased_L-4_H-256_A-4", 256], #256, 4L, 4A
               "BERT-Mini": ["google/bert_uncased_L-4_H-128_A-2", 128],#128, 4L, 2A
               "BERT-Tiny": ["google/bert_uncased_L-2_H-128_A-2", 128]}#128, 2L, 2A

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
max_length = 512
batch_size = 32
model_url = bert_models["BERT-Small"][0]
output_dim = ball_dims[test_root]
model_norm = nballBertNorm(model_url, output_dim).to(device)
train_one_tree(model_norm, test_root, filtered_corpra, device)
# Out:
# loading balls....
# 371 balls are loaded
#
# Smallest 10 elements in nball_norms: [1000000.0, 1000000.0, 1000000.0, 1000000.0, 1000000.0, 1000253.7134719943, 1050574.900727731, 1050574.900727731, 1050633.9614014437, 1050952.2580102002]
# Largest 10 elements in nball_norms: [41091969.115863234, 41091969.115863234, 41091969.115863234, 42037461.95414666, 42048329.80491032, 42095926.466105804, 42170830.46417026, 42488832.319365725, 43050345.80513795, 47847915.97634286]
# Smallest 10 elements in nball_radius: [0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.00010505749007277309, 0.00010505749007277309, 0.00011086365831506724, 0.00011721868918547535, 0.00011721868918547535]
# Largest 10 elements in nball_radius: [1503900.3829487448, 1516117.3656599831, 1658496.209105272, 2366441.4549796684, 2889502.3717317907, 5162067.0717816185, 23139354.02628052, 26681987.743101574, 42092728.28523759, 46988174.82434979]
# Tokenizing sentences...
# Tokenizing finished.
# Calculating word indices...
# Tokenizing finished.
# Epoch 1/50: 100%|█████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 12.26it/s, loss=0.0139]
# Epoch 1, Avg Loss: 0.015977193053592655, Improvement: 0
# Epoch 2/50: 100%|████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.09it/s, loss=0.00604]
# Epoch 2, Avg Loss: 0.007604574127232327, Improvement: 0.008372618926360327
# Epoch 3/50: 100%|████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.07it/s, loss=0.00345]
# Epoch 3, Avg Loss: 0.004437891204896218, Improvement: 0.0031666829223361086
# Epoch 4/50: 100%|████████████████████████████████████████████████████████| 17/17 [00:01<00:00, 13.00it/s, loss=0.00319]
# Epoch 4, Avg Loss: 0.003215851659393486, Improvement: 0.0012220395455027327
# Epoch 5/50:  35%|████████████████████                                     | 6/17 [00:00<00:00, 11.02it/s, loss=0.00224]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 14
#      12 output_dim = ball_dims[test_root]
#      13 model_norm = nballBertNorm(model_url, output_dim).to(device)
# ---> 14 train_one_tree(model_norm, test_root, filtered_corpra, device)
#
# Cell In[19], line 48, in train_one_tree(model_norm, root, training_data, device)
#      46 scheduler_norm = StepLR(optimizer_norm, step_size=50, gamma=0.1)
#      47 # Train_norm
# ---> 48 train(model=model_norm, \
#      49       dataloader=dataloader_train,\
#      50       optimizer=optimizer_norm,\
#      51       scheduler=scheduler_norm,\
#      52       num_epochs=50, \
#      53       mode="norm",
#      54       nball_target=nball_norms)
#
# Cell In[32], line 34, in train(model, dataloader, optimizer, scheduler, num_epochs, mode, nball_target)
#      31     loss.backward()
#      32     optimizer.step()
# ---> 34     total_loss += loss.item()
#      35     progress_bar.set_postfix(loss=loss.item())
#      37 # Logging average metrics per epoch
#
# KeyboardInterrupt:

# %%
# Check the dimenstion of all:
dims = []
for root in roots:
    nball_path = '../data/entity_multi/' + root + "_nball.txt"
    dims.append(load_ball_dims(nball_path))

print(max(dims))
